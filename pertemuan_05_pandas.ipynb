# %% [markdown]
# # Hacktiv8-PTP Python For Data Science // S.4 // Pandas

# %% [markdown]
# ## Komponen dan aplikasi panda
#   library pandas terdiri dari komponen-komponen

# %% [markdown]
# - pandas/core: Ini berisi implementasi dari struktur data dasar panda, seperti Series dan DataFrames. Series dan DataFrames adalah kumpulan alat dasar yang sangat berguna untuk manipulasi data dan digunakan secara luas oleh ilmuwan data.
#
# - pandas/src: Ini terdiri dari algoritma yang menyediakan fungsionalitas dasar panda. Fungsionalitas ini adalah bagian dari arsitektur panda, yang tidak akan Anda gunakan secara eksplisit. Lapisan ini ditulis dalam C atau Cython.
#
# - pandas/io: Ini terdiri dari kumpulan alat untuk input dan output file dan data. Kumpulan alat ini memfasilitasi input data dari sumber seperti CSV dan teks dan memungkinkan Anda menulis data ke format seperti teks dan CSV.
#
# - pandas/tools: Lapisan ini berisi semua kode dan algoritma untuk fungsi dan metode panda, seperti merge, join, dan concat.
#
# - pandas/sparse: Ini berisi fungsionalitas untuk menangani nilai yang hilang dalam struktur datanya, seperti DataFrames dan Series.
#
# - pandas/stats: Ini berisi seperangkat alat untuk menangani fungsi statistik seperti regresi dan klasifikasi.
#
# - pandas/util: Ini berisi semua utilitas untuk men-debug perpustakaan.
#
# - pandas/rpy: Ini adalah antarmuka untuk menghubungkan ke R.

# %% [markdown]
# ## Objek Seri
#
# Dalam panda, data satu dimensi direpresentasikan sebagai objek Seri. Objek seri diinisialisasi menggunakan pd.Series() konstruktor.

# %% [markdown]
# * Series sangat mirip dengan array NumPy (sebenarnya dibangun di atas object array NumPy).
# * Apa yang membedakan array NumPy dari series adalah bahwa series dapat memiliki axis label, artinya dapat di indeks oleh label, bukan hanya lokasi nomor.
# * Itu juga tidak perlu menyimpan data numerik, bisa menampung apa saja python object.

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
series2 = pd.Series([[10,20],[30,40.4, 'Series'],[50,60], {'name':'ketut', 'org':'community'}])

# %%
print(series2)

# %% [markdown]
# _______

# %%
vars = pd.Series()
print(vars)

# %%
datanp = np.array(['x','y','z','a','b','c','d','e','f'])
dataser = pd.Series(datanp)
print(dataser)
print(dataser.index)

# %%
datanp = np.array(['x','y','z','a','b','c'])
dataser = pd.Series(datanp, index=[20,21,23,24,25,26])
print(dataser)
print(dataser.index)

# %%
data_dic = {'A':0.7,'B':0, 'C':10.5, 'D':1}
pds = pd.Series(data_dic)
print(pds)

# %%
pds_new = pd.Series(data_dic, index=['A','B','E',14])
print(pds_new)

# %%
pds_val7 = pd.Series(7, index=[1, 2, 3, 4, 5])
print(pds_val7)

# %%
np_abc = np.array(['a', 'b', 'c', 'd', 'e','f'])
dts = pd.Series(np_abc)
print(dts)

# %%
print(dts[0:3])

# %%
print(dts[:4])

# %%
npv = np.array([10,20,40,50,60,70,80])
pds = pd.Series(npv, index=['a','b','c','d','e','f','g'])
print(pds)

# %%
print(pds['a'])

# %%
print(pds['d':'f'])

# %%
print(pds.index)
print(pds.values)

# %%
datan = pd.Series([1, 2, 3,4,5,6,7,8], index =[1, 2, 5,6,7,8,9,10])
print(datan)
print(datan.index)

# %%
# print(datan.loc[5]) # 3 
##print(datan.loc[2:6])
print(datan.loc[[2,6,8,10]])

# %%
print(datan.values)
print(datan.values>=4)

# %%
kondisi = datan.values>=4
print(datan.loc[kondisi])

# %%
print(datan)

# %%
print(datan.iloc[3])

# %% [markdown]
# ---------

# %% [markdown]
# ## DataFrames

# %% [markdown]
#  DataFrame adalah representasi data dua dimensi dalam baris dan kolom, yang dapat diinisialisasi dalam panda menggunakan DataFrame()konstruktor.
#
#  DataFrames sangat bagus untuk merepresentasikan data nyata:
#         baris sesuai dengan instance (objek, observasi, dll.), dan kolom sesuai
#         dengan features untuk setiap instance.

# %%
data_dic  = {
        'name': ['Joko','Jono','Joni','Jhon'], 
        'age':[20,50,30,40], 
        'address': ['Jkt','BDG','SBY','SOLO'],
        'qualif': ['Msc','Prof','Ir','Phd']
}
print(data_dic)

# %%
df = pd.DataFrame(data_dic)
print(df)

# %%
print(df[['name','qualif']])

# %%
kondisiphd = df['qualif'] == 'Phd'

# %%
print(df.loc[kondisiphd])

# %%
dfangka = pd.DataFrame({'x':[2,3], 'y':[10,20]})
print(dfangka)

# %%
dfapl = dfangka.apply(lambda z: z* 3)
print(dfapl)

# %%
def square(a):
    return a*a

# %%
print(dfangka)

# %%
dfsquare = dfangka.apply(square)
print(dfsquare)

# %% [markdown]
# ______

# %%
pip install requests

# %%
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv'

# %%
import requests

# %%
response = requests.get(url)
print(type(response))
print(response.status_code) ## 200 success ,
print(response.content)

with open('nba_elo.csv', 'wb') as f : 
    f.write(response.content)

# %%
import pandas as pd 
import numpy as np

pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv('nba_elo.csv')

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
pd.set_option("display.max.columns",None) # keselurahan colum

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0            0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# ...

# %%
pd.set_option("display.precision",2)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %% [markdown]
# |Header	|Definition|
# |:-----|:-------|
# |gameorder|	Play order of game in NBA history |
# | game_id	| Unique ID for each game |
# |lg_id	| Which league the game was played in |
# | `_iscopy` | 	Each row of data is tied to a single team for a single game, so `_iscopy` flags if this game_id has already occured for the opposing team in the same matchup
# | year_id	| Season id, named based on year in which the season ended |
# | date_game	| Game date |
# | is_playoffs	| Flag for playoff games |
# | team_id	| Three letter code for team name, from Basketball Reference |
# | fran_id	| Franchise id. Multiple team_ids can fall under the same fran_id due to name changes or moves. Interactive is grouped by fran_id.
# | pts |	Points scored by team |
# | elo_i	| Team elo entering the game |
# | elo_n	| Team elo following the game |
# | win_equiv	| Equivalent number of wins in a 82-game season for a team of elo_n quality |
# | opp_id |	Team id of opponent |
# | opp_fran |	Franchise id of opponent |
# | opp_pts |	Points scored by opponent / point pertandingan |
# | opp_elo_i	 | Opponent elo entering the game, sebagai team lawan (Elo sebelum main ) |
# | opp_elo_n	| Opponent elo following the game, sebagai team lawan (Elo setelah main) |
# | game_location	| Home (H), away (A), or neutral (N) |
# | game_result |	Win or loss for team in the team_id column |
# | forecast |	Elo-based chances of winning for the team in the team_id column, based on elo  ratings and game location
# |notes|	Additional informatio |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df['fran_id'] == 'Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %%
df.loc[df['fran_id'] == 'Lakers','team_id']
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
df.loc[df['fran_id'] == 'Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL','date_game'].value_counts()
# Out:
# 11/4/1948     1
# 11/15/1956    1
# 3/16/1956     1
# 3/17/1956     1
# 3/19/1956     1
#              ..
# 11/29/1952    1
# 11/30/1952    1
# 12/1/1952     1
# 12/3/1952     1
# 3/26/1960     1
# Name: date_game, Length: 946, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL','date_game'].max()
# Out:
# '4/9/1959'

# %%
df.loc[df['team_id'] == 'MNL','date_game'].min()
# Out:
# '1/1/1949'

# %%
# Out:
# 0         11/1/1946
# 1         11/1/1946
# 2         11/2/1946
# 3         11/2/1946
# 4         11/2/1946
#             ...
# 126309    6/11/2015
# 126310    6/14/2015
# 126311    6/14/2015
# 126312    6/16/2015
# 126313    6/16/2015
# Name: date_game, Length: 126314, dtype: object

# %%
df['date_played'] = pd.to_datetime(df['date_game'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.loc[df['team_id'] == 'MNL','date_game'].max()
# Out:
# '4/9/1959'

# %%
df.loc[df['team_id'] == 'MNL','date_played'].max()
# Out:
# Timestamp('1960-03-26 00:00:00')

# %%
df.loc[df['team_id'] == 'MNL','date_played'].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %%
df.loc[df['team_id'] == 'MNL','date_played'].agg(('min','max'))
# Out:
# min   1948-11-04
# max   1960-03-26
# Name: date_played, dtype: datetime64[ns]

# %%
df.loc[df['team_id'] == 'DET','pts'].sum()
# Out:
# 516438

# %%
df.loc[df['team_id'] == 'DET','date_played'].apply(lambda y: y.year).unique()
# Out:
# array([1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015])

# %% [markdown]
# menghitung rata2

# %%
total_point_dt = df.loc[df['team_id'] == 'DET','pts'].sum()
print(total_point_dt)
# Out:
# 516438

# %%
tahun_dt = df.loc[df['team_id'] == 'DET','date_played'].apply(lambda y: y.year).unique()
print(tahun_dt)
# Out:
# [1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969 1970
#  1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015]

# %%
total_point_dt / len(tahun_dt)
# Out:
# 8753.186440677966

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
#         'date_played'],
#        dtype='object')]

# %%
df.keys()
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
#        'date_played'],
#       dtype='object')

# %%
'pts' in df.keys()
# Out:
# True

# %% [markdown]
# * .loc
# * .iloc
#
#
# |notes    | loc    | iloc |
# |:--------|:-------|:-----|
# |a value   | ```loc['label'] or loc[0]``` <br> single label or integer  |```iloc[1]``` single integer |
# |a list |  ```loc[['label','label2]] ```  <br>  A list of labe | ``` iloc[[1,2,3]]``` list integers
# | slicing |  ```loc[['A':'B']] ```  <br> A and B Include     | ``` iloc[n:m]```, n is include m exclude |
# | Condition |   bool series or list        | bool list |
# | Callable function | ```loc[lambda A: A[2]] ```  |  ```iloc[lambda A: A[2]] ``` |

# %% [markdown]
# ## Query data set

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
data2011 = df[df['year_id'] > 2010]
print(data2011)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
data2011.shape
# Out:
# (12658, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df['notes'].notnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: notes, Length: 126314, dtype: bool

# %%
df_notes = df[df['notes'].notnull()]

# %%
df_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
df_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5424 entries, 930 to 124863
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameorder      5424 non-null   int64
#  1   game_id        5424 non-null   object
#  2   lg_id          5424 non-null   object
#  3   _iscopy        5424 non-null   int64
#  4   year_id        5424 non-null   int64
#  5   date_game      5424 non-null   object
#  6   seasongame     5424 non-null   int64
#  7   is_playoffs    5424 non-null   int64
#  8   team_id        5424 non-null   object
#  9   fran_id        5424 non-null   object
#  10  pts            5424 non-null   int64
#  11  elo_i          5424 non-null   float64
#  12  elo_n          5424 non-null   float64
#  13  win_equiv      5424 non-null   float64
#  14  opp_id         5424 non-null   object
#  15  opp_fran       5424 non-null   object
#  16  opp_pts        5424 non-null   int64
# ...

# %%
df[df['fran_id'].str.endswith('ers')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
df[  (df['team_id']=='BLB') & (df['pts']< 100) & (df['pts']> 50) ]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 701         351  194711120WSC   NBA        1     1948  11/12/1947           1
# 702         352  194711130BLB   NBA        0     1948  11/13/1947           2
# 714         358  194711150CHS   NBA        1     1948  11/15/1947           3
# 729         365  194711200BLB   NBA        0     1948  11/20/1947           4
# 737         369  194711210BOS   NBA        1     1948  11/21/1947           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 5902       2952  195403080MLH   NBA        1     1954    3/8/1954          68
# 5904       2953  195403081MLH   NBA        1     1954    3/8/1954          69
# 5913       2957  195403100BLB   NBA        0     1954   3/10/1954          70
# 5927       2964  195403130BOS   NBA        1     1954   3/13/1954          71
# 5936       2969  195403140FTW   NBA        1     1954   3/14/1954          72
#
# ...

# %%
grp_franid = df.groupby('fran_id', sort=False)
print(grp_franid)
grp_franid['pts'].sum()
# Out:
# ...
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
[df[(df['fran_id']=='Celtics') & ( df['year_id'] > 2000)  ].groupby(['year_id','game_result'])['game_id'].count()]
# Out:
# [year_id  game_result
#  2001     L              46
#           W              36
#  2002     L              40
#           W              58
#  2003     L              44
#           W              48
#  2004     L              50
#           W              36
#  2005     L              41
#           W              48
#  2006     L              49
#           W              33
#  2007     L              58
#           W              24
#  2008     L              26
#           W              82
#  2009     L              27
#           W              69
#  2010     L              41
#           W              65
#  2011     L              30
#           W              61
#  2012     L              36
#           W              50
#  2013     L              44
#           W              43
#  2014     L              57
#           W              25
#  2015     L              46
#           W              40
#  Name: game_id, dtype: int64]

# %%
nba_new = df.copy()
nba_new.shape
# Out:
# (126314, 24)

# %%
nba_new['pts'] - nba_new['opp_pts']
# Out:
# 0         -2
# 1          2
# 2         16
# 3        -16
# 4        -17
#           ..
# 126309   -21
# 126310    13
# 126311   -13
# 126312    -8
# 126313     8
# Length: 126314, dtype: int64

# %%
nba_new['selesih_point'] = df.pts - df.opp_pts

# %%
nba_new
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...   opp_fran  opp_pts  \
# 0                1            0     TRH    Huskies  ...     Knicks       68
# ...

# %%
nba_new['selesih_point'].min()
nba_new['selesih_point'].max()
# Out:
# 68

# %% [markdown]
# _____

# %%
pip install matplotlib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
nba_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0            0     TRH  Huskies  ...    Knicks       68  1300.0000  1306.7233
# 1            0     NYK   Knicks  ...   Huskies       66  1300.0000  1293.2767
# 2            0     CHS    Stags  ...    Knicks       47  1306.7233  1297.0712
# 3            0     NYK   Knicks  ...     Stags       63  1300.0000  1309.6521
# 4            0     DTF  Falcons  ...  Capitols       50  1300.0000  1320.3811
#
# ...

# %%
knight_pts = nba_new[nba_new['fran_id']=='Knicks'].groupby('year_id')['pts'].sum()

# %%
knight_pts.plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='year_id'>

# %%
pip install sqlalchemy
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.4/241.4 kB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
pip install cryptography
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 7.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 5.3 MB/s eta 0:00:00
# ...
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
pip install pymysql
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pymysql 
import pandas as pd

# %%
table_name = 'python'

# %%
data_dic ={"UserId":["xxxxx", "yyyyy", "zzzzz", "aaaaa", "bbbbb", "ccccc", "ddddd"],

            "UserFavourite":["Greek Salad", "Philly Cheese Steak", "Turkey Burger", "Crispy Orange Chicken", "Atlantic Salmon", "Pot roast", "Banana split"],

            "MonthlyOrderFrequency":[5, 1, 2, 2, 7, 6, 1],

            "HighestOrderAmount":[30, 20, 16, 23, 20, 26, 9],

            "LastOrderAmount":[21,20,4,11,7,7,7],

            "LastOrderRating":[3,3,3,2,3,2,4],

            "AverageOrderRating":[3,4,2,1,3,4,3],

            "OrderMode":["Web", "App", "App", "App", "Web", "Web", "App"],

            "InMedicalCare":["No", "No", "No", "No", "Yes", "No", "No"]};

# %%
dataframe = pd.DataFrame(data=data_dic)
dataframe.head()
# Out:
#   UserId          UserFavourite  MonthlyOrderFrequency  HighestOrderAmount  \
# 0  xxxxx            Greek Salad                      5                  30
# 1  yyyyy    Philly Cheese Steak                      1                  20
# 2  zzzzz          Turkey Burger                      2                  16
# 3  aaaaa  Crispy Orange Chicken                      2                  23
# 4  bbbbb        Atlantic Salmon                      7                  20
#
#    LastOrderAmount  LastOrderRating  AverageOrderRating OrderMode  \
# 0               21                3                   3       Web
# 1               20                3                   4       App
# 2                4                3                   2       App
# 3               11                2                   1       App
# 4                7                3                   3       Web
#
#   InMedicalCare
# 0            No
# 1            No
# 2            No
# 3            No
# 4           Yes

# %%
sqlEngine = create_engine("mysql+pymysql://userpython:H8pytn014@localhost:6603/PYTNKS014",
                                pool_recycle=3600, echo=True)

# %%
dbconnection = sqlEngine.connect()
# Out:
# 2023-03-13 21:40:16,584 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-03-13 21:40:16,586 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-03-13 21:40:16,591 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-03-13 21:40:16,592 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-03-13 21:40:16,596 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-03-13 21:40:16,597 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
try : 
    dataframe.to_sql(table_name,dbconnection,if_exists='fail')
except ValueError as ve:
    print(ve)
except Exception as ex:
    print(ex)
else: 
    print("Table create success")
#finally:
    #dbconnection.close()
# Out:
# 2023-03-13 21:40:18,902 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-13 21:40:18,909 INFO sqlalchemy.engine.Engine DESCRIBE `pytnks014`.`python`
# 2023-03-13 21:40:18,911 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-03-13 21:40:18,939 INFO sqlalchemy.engine.Engine
# CREATE TABLE python (
# 	`index` BIGINT,
# 	`UserId` TEXT,
# 	`UserFavourite` TEXT,
# 	`MonthlyOrderFrequency` BIGINT,
# 	`HighestOrderAmount` BIGINT,
# 	`LastOrderAmount` BIGINT,
# 	`LastOrderRating` BIGINT,
# 	`AverageOrderRating` BIGINT,
# 	`OrderMode` TEXT,
# 	`InMedicalCare` TEXT
# )
#
#
# 2023-03-13 21:40:18,940 INFO sqlalchemy.engine.Engine [no key 0.00118s] {}
# 2023-03-13 21:40:19,006 INFO sqlalchemy.engine.Engine CREATE INDEX ix_python_index ON python (`index`)
# 2023-03-13 21:40:19,007 INFO sqlalchemy.engine.Engine [no key 0.00112s] {}
# ...

# %% [markdown]
# iloc with index number
